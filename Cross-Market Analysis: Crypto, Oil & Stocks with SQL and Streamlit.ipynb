# %% [markdown]
# <a href="https://colab.research.google.com/github/vaidegiarch/Cross-Market-Analysis-Crypto-Oil-Stocks-with-SQL-and-Streamlit/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import requests
import time

# %%
base_url="https://api.coingecko.com/api/v3/coins/markets"
all_records=[]

for page in range(1,6):#shows data 1 to 5 page

  url=(f"{base_url}?vs_currency=inr&per_page=250&order=market_cap_desc&page={page}&sparkline=False")
  response=requests.get(url)#gets data from url

  if response.status_code==200:
    data=response.json()
    all_records.extend(data)
    print (f"page{page} fetched successfully")

  else:
    print (f"failed to fetch page{page}")

  time.sleep(30)

print ("total records collected:",len (all_records))
# Out:
# page1 fetched successfully
# page2 fetched successfully
# page3 fetched successfully
# page4 fetched successfully
# page5 fetched successfully
# total records collected: 1250

# %%
len(all_records)
# Out:
# 1250

# %%
data=all_records

records=[]

for i in data:
  records.append(dict(id=i["id"],
                     symbol=i["symbol"],
                     name=i["name"],
                     current_price=i["current_price"],
                     market_cap=i["market_cap"],
                     market_cap_rank=i["market_cap_rank"],
                     total_volume=i["total_volume"],
                     circulating_supply=i["circulating_supply"],
                     total_supply=i["total_supply"],
                     ath=i["ath"],
                     atl=i["atl"],
                     last_updated=i["last_updated"]))

# %%
import pandas as pd
Cryptocurrencies_df=pd.DataFrame(records)
Cryptocurrencies_df
# Out:
#                      id  symbol                 name  current_price  \
# 0               bitcoin     btc              Bitcoin   5.978426e+06
# 1              ethereum     eth             Ethereum   1.712600e+05
# 2                tether    usdt               Tether   9.084000e+01
# 3                ripple     xrp                  XRP   1.243600e+02
# 4           binancecoin     bnb                  BNB   5.462700e+04
# ...                 ...     ...                  ...            ...
# 1245      bitrise-token   brise              Bitgert   1.960000e-06
# 1246      landwolf-0x67    wolf             LandWolf   8.572700e-04
# 1247      localcoinswap     lcs        LocalCoinSwap   2.011000e+01
# 1248  bitcoin-usd-btcfi  btcusd  Bitcoin USD (BTCFi)   9.040000e+01
# 1249               pivx    pivx                 PIVX   7.620000e+00
#
#            market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0     119492824100063                1  3.561193e+12        1.999344e+07
# ...

# %%
Cryptocurrencies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1250 non-null   object
#  1   symbol              1250 non-null   object
#  2   name                1250 non-null   object
#  3   current_price       1250 non-null   float64
#  4   market_cap          1250 non-null   int64
#  5   market_cap_rank     1250 non-null   int64
#  6   total_volume        1234 non-null   float64
#  7   circulating_supply  1250 non-null   float64
#  8   total_supply        1248 non-null   float64
#  9   ath                 1250 non-null   float64
#  10  atl                 1250 non-null   float64
#  11  last_updated        1250 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 117.3+ KB

# %%
Cryptocurrencies_df["last_updated"]=pd.to_datetime(Cryptocurrencies_df["last_updated"]).dt.date
Cryptocurrencies_df["last_updated"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1250 entries, 0 to 1249
# Series name: last_updated
# Non-Null Count  Dtype
# --------------  -----
# 1250 non-null   object
# dtypes: object(1)
# memory usage: 9.9+ KB

# %%
Cryptocurrencies_df.rename(columns={"last_updated": "date"}, inplace=True)

# %%
Cryptocurrencies_df # 1.data frame of all cryptocoins
# Out:
#                      id  symbol                 name  current_price  \
# 0               bitcoin     btc              Bitcoin   5.978426e+06
# 1              ethereum     eth             Ethereum   1.712600e+05
# 2                tether    usdt               Tether   9.084000e+01
# 3                ripple     xrp                  XRP   1.243600e+02
# 4           binancecoin     bnb                  BNB   5.462700e+04
# ...                 ...     ...                  ...            ...
# 1245      bitrise-token   brise              Bitgert   1.960000e-06
# 1246      landwolf-0x67    wolf             LandWolf   8.572700e-04
# 1247      localcoinswap     lcs        LocalCoinSwap   2.011000e+01
# 1248  bitcoin-usd-btcfi  btcusd  Bitcoin USD (BTCFi)   9.040000e+01
# 1249               pivx    pivx                 PIVX   7.620000e+00
#
#            market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0     119492824100063                1  3.561193e+12        1.999344e+07
# ...

# %% [markdown]
# historical price for three coins

# %%
import requests
from datetime import datetime
import time

coin_ids = ["bitcoin", "ethereum", "tether"]
all_price_records = []  # ✅ must be empty

for coin_id in coin_ids:
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart?vs_currency=inr&days=365"

    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        # Loop through daily prices
        for price_entry in data['prices']:
            timestamp, price = price_entry
            date = datetime.utcfromtimestamp(timestamp / 1000).date()

            # Add to our list
            all_price_records.append({
                "coin_id": coin_id,
                "date": date,
                "price_inr": price
            })
        print(f"{coin_id} prices fetched")
    else:
        print(f"Failed to fetch {coin_id}")

    time.sleep(30)  # polite delay to avoid API rate limits
# Out:
# /tmp/ipython-input-90423288.py:18: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   date = datetime.utcfromtimestamp(timestamp / 1000).date()
# bitcoin prices fetched
# ethereum prices fetched
# tether prices fetched

# %%
Crypto_prices_df=pd.DataFrame(all_price_records)

# %%
Crypto_prices_df["coin_id"].value_counts()
# Out:
# coin_id
# bitcoin     366
# ethereum    366
# tether      366
# Name: count, dtype: int64

# %%
Crypto_prices_df  # 2. data frame of top 3 coins -historical prices for 1 year (each coin)
# Out:
#       coin_id        date     price_inr
# 0     bitcoin  2025-02-24  8.341958e+06
# 1     bitcoin  2025-02-25  7.922798e+06
# 2     bitcoin  2025-02-26  7.729282e+06
# 3     bitcoin  2025-02-27  7.314307e+06
# 4     bitcoin  2025-02-28  7.397417e+06
# ...       ...         ...           ...
# 1093   tether  2026-02-20  9.101081e+01
# 1094   tether  2026-02-21  9.069154e+01
# 1095   tether  2026-02-22  9.070614e+01
# 1096   tether  2026-02-23  9.069543e+01
# 1097   tether  2026-02-23  9.083841e+01
#
# [1098 rows x 3 columns]

# %% [markdown]
# oil prices

# %%
import pandas as pd
oil_df = pd.read_csv("https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv")

oil_df

oil_df["Date"]=pd.to_datetime(oil_df["Date"])


Oil_prices_df=oil_df[
    (oil_df["Date"]>="2020-01-01")&
    (oil_df["Date"]<="2026-01-31")]

# %%
Oil_prices_df
# Out:
#             Date  Price
# 8569  2020-01-02  61.17
# 8570  2020-01-03  63.00
# 8571  2020-01-06  63.27
# 8572  2020-01-07  62.70
# 8573  2020-01-08  59.65
# ...          ...    ...
# 10084 2026-01-26  60.46
# 10085 2026-01-27  62.04
# 10086 2026-01-28  62.75
# 10087 2026-01-29  64.77
# 10088 2026-01-30  64.50
#
# [1520 rows x 2 columns]

# %%
Oil_prices_df.reset_index(drop=True, inplace=True)
Oil_prices_df # 3.data frame of oil prices from Jan 2020 – Jan 2026.
# Out:
#            Date  Price
# 0    2020-01-02  61.17
# 1    2020-01-03  63.00
# 2    2020-01-06  63.27
# 3    2020-01-07  62.70
# 4    2020-01-08  59.65
# ...         ...    ...
# 1515 2026-01-26  60.46
# 1516 2026-01-27  62.04
# 1517 2026-01-28  62.75
# 1518 2026-01-29  64.77
# 1519 2026-01-30  64.50
#
# [1520 rows x 2 columns]

# %% [markdown]
# Stock Prices (Yahoo Finance API)

# %%
import yfinance as yf
import pandas as pd

tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2026-01-12"

stocks_df = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")
stocks_df.head()
# Out:
# /tmp/ipython-input-2364413695.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stocks_df = yf.download(tickers, start=start_date, end=end_date, group_by="ticker")
# [*********************100%***********************]  3 of 3 completed
# Ticker             ^NSEI                                                      \
# Price               Open          High           Low         Close    Volume
# Date
# 2020-01-01  12202.150391  12222.200195  12165.299805  12182.500000  304100.0
# 2020-01-02  12198.549805  12289.900391  12195.250000  12282.200195  407700.0
# 2020-01-03  12261.099609  12265.599609  12191.349609  12226.650391  428800.0
# 2020-01-06  12170.599609  12179.099609  11974.200195  11993.049805  396500.0
# 2020-01-07  12079.099609  12152.150391  12005.349609  12052.950195  447800.0
#
# Ticker            ^GSPC                                                       \
# ...

# %%
stock_prices_df=stocks_df[["^GSPC", "^IXIC", "^NSEI"]].reset_index().dropna()#dropped null values using list
stock_prices_df # 4 data frame --of yahoo finace stock prices
# Out:
# Ticker       Date        ^GSPC                                         \
# Price                     Open         High          Low        Close
# 1      2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 2      2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 3      2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 4      2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
# 5      2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049
# ...           ...          ...          ...          ...          ...
# 1558   2026-01-05  6892.189941  6920.379883  6891.560059  6902.049805
# 1559   2026-01-06  6908.029785  6948.689941  6904.020020  6944.819824
# 1560   2026-01-07  6945.069824  6965.689941  6919.189941  6920.930176
# 1561   2026-01-08  6914.109863  6931.279785  6899.330078  6921.459961
# 1562   2026-01-09  6927.830078  6978.359863  6917.640137  6966.279785
#
# ...

# %% [markdown]
# sql queries

# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import sqlite3
conn = sqlite3.connect("Cryptocurrencies.db")
cursor = conn.cursor()
print("SQLite connected")
# Out:
# SQLite connected

# %%
# Pushing dataframe into sql

Cryptocurrencies_df.to_sql("Cryptocurrencies", conn, if_exists="replace", index=False)
# Out:
# 1250

# %%
print(Cryptocurrencies_df.columns)
# Out:
# Index(['id', 'symbol', 'name', 'current_price', 'market_cap',
#        'market_cap_rank', 'total_volume', 'circulating_supply', 'total_supply',
#        'ath', 'atl', 'date'],
#       dtype='object')

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Cryptocurrencies (
    id VARCHAR(50) PRIMARY KEY,
    symbol VARCHAR(10),
    name VARCHAR(100),
    current_price DECIMAL(18, 6),
    market_cap BIGINT,
    market_cap_rank INT,
    total_volume BIGINT,
    circulating_supply DECIMAL(20, 6),
    total_supply DECIMAL(20, 6),
    ath DECIMAL(18, 6),
    atl DECIMAL(18, 6),
    date DATE)""")

# %%
sql = """
INSERT or REPLACE INTO Cryptocurrencies (id, symbol, name, current_price,market_cap,
       market_cap_rank, total_volume, circulating_supply, total_supply,
       ath, atl, date)
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ? )
"""

# %%
data = Cryptocurrencies_df[["id","symbol","name","current_price", 'market_cap',
       'market_cap_rank', 'total_volume', 'circulating_supply', 'total_supply',
       'ath', 'atl', 'date']].values.tolist()

# %%
cursor.executemany(sql, data)
conn.commit()

# %%
cursor.execute("SELECT * FROM Cryptocurrencies LIMIT 10")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('bitcoin', 'btc', 'Bitcoin', 5978426.0, 119492824100063, 1, 3561192576684.0, 19993440.0, 19993440.0, 11187013.0, 3993.42, '2026-02-23')
# ('ethereum', 'eth', 'Ethereum', 171260.0, 20665183551559, 2, 1515936824091.0, 120692355.0689789, 120692355.0689789, 431946.0, 28.13, '2026-02-23')
# ('tether', 'usdt', 'Tether', 90.84, 16680747314099, 3, 5699465365552.0, 183624238441.843, 189091175734.4462, 105.52, 36.86, '2026-02-23')
# ('ripple', 'xrp', 'XRP', 124.36, 7580152143181, 4, 234998067450.0, 61018583977.0, 99985712847.0, 313.99, 0.159343, '2026-02-23')
# ('binancecoin', 'bnb', 'BNB', 54627.0, 7444065516099, 5, 94090382146.0, 136359026.0799999, 136359026.0799999, 121422.0, 2.58, '2026-02-23')
# ('usd-coin', 'usdc', 'USDC', 90.85, 6761710399228, 6, 756821233186.0, 74428856046.35391, 74432898545.46739, 1327.87, 65.31, '2026-02-23')
# ('solana', 'sol', 'Solana', 7166.93, 4071704815825, 7, 347327805864.0, 568474330.1417973, 620928834.6978452, 25396.0, 38.03, '2026-02-23')
# ...

# %%
cursor.execute("""SELECT * from Cryptocurrencies
order by market_cap_rank asc
limit 3""")

rows = cursor.fetchall()

for row in rows:
    print(row)    # Find the top 3 cryptocurrencies by market cap.
# Out:
# ('bitcoin', 'btc', 'Bitcoin', 5978426.0, 119492824100063, 1, 3561192576684.0, 19993440.0, 19993440.0, 11187013.0, 3993.42, '2026-02-23')
# ('bitcoin', 'btc', 'Bitcoin', 5978426.0, 119492824100063, 1, 3561192576684.0, 19993440.0, 19993440.0, 11187013.0, 3993.42, '2026-02-23')
# ('ethereum', 'eth', 'Ethereum', 171260.0, 20665183551559, 2, 1515936824091.0, 120692355.0689789, 120692355.0689789, 431946.0, 28.13, '2026-02-23')

# %%
cursor.execute("""SELECT id,symbol,name,circulating_supply, total_supply
from Cryptocurrencies
where circulating_supply > 0.9 * total_supply""")

rows = cursor.fetchall()

for row in rows:
    print(row)  #List all coins where circulating supply exceeds 90% of total supply.
# Out:
# ('bitcoin', 'btc', 'Bitcoin', 19993440.0, 19993440.0)
# ('ethereum', 'eth', 'Ethereum', 120692355.0689789, 120692355.0689789)
# ('tether', 'usdt', 'Tether', 183624238441.843, 189091175734.4462)
# ('binancecoin', 'bnb', 'BNB', 136359026.0799999, 136359026.0799999)
# ('usd-coin', 'usdc', 'USDC', 74428856046.35391, 74432898545.46739)
# ('solana', 'sol', 'Solana', 568474330.1417973, 620928834.6978452)
# ('tron', 'trx', 'TRON', 94730601626.2116, 94735278179.03369)
# ('dogecoin', 'doge', 'Dogecoin', 168830643126.5791, 168853803126.5791)
# ('figure-heloc', 'figr_heloc', 'Figure Heloc', 15224003657.427, 15224003657.427)
# ('bitcoin-cash', 'bch', 'Bitcoin Cash', 19998946.77165078, 19999156.14665078)
# ('usds', 'usds', 'USDS', 9889121116.640924, 9889121116.640924)
# ('leo-token', 'leo', 'LEO Token', 921306944.9, 985239504.0)
# ('ethena-usde', 'usde', 'Ethena USDe', 6148720059.803138, 6148720059.803138)
# ('canton-network', 'cc', 'Canton', 37816248801.26848, 37816248801.26848)
# ...

# %%
cursor.execute("""SELECT name,symbol,current_price,ath
from Cryptocurrencies
where current_price >=0.9* ath """)

rows = cursor.fetchall()

for row in rows:
    print(row) #Get coins that are within 10% of their all-time-high (ATH).
# Out:
# ('USDS', 'usds', 90.83, 92.23)
# ('Ethena USDe', 'usde', 90.81, 92.91)
# ('USD1', 'usd1', 90.78, 92.17)
# ('Rain', 'rain', 0.901026, 0.989197)
# ('Dai', 'dai', 90.85, 92.29)
# ('PayPal USD', 'pyusd', 90.83, 92.2)
# ('Tether Gold', 'xaut', 465381.0, 514631.0)
# ('PAX Gold', 'paxg', 468546.0, 516779.0)
# ('BlackRock USD Institutional Digital Liquidity Fund', 'buidl', 90.85, 92.2)
# ('Falcon USD', 'usdf', 90.61, 92.45)
# ('Circle USYC', 'usyc', 101.11, 102.4)
# ('Ripple USD', 'rlusd', 90.84, 92.15)
# ('BFUSD', 'bfusd', 90.78, 92.02)
# ('Superstate Short Duration U.S. Government Securities Fund (USTB)', 'ustb', 999.28, 1011.63)
# ('USDtb', 'usdtb', 91.15, 95.66)
# ('Spiko EU T-Bills Money Market Fund', 'eutbl', 112.39, 115.38)
# ('USDD', 'usdd', 90.84, 92.2)
# ('Janus Henderson Anemoy AAA CLO Fund', 'jaaa', 93.3, 94.38)
# ('OUSG', 'ousg', 10390.8, 10520.12)
# ('pippin', 'pippin', 64.3, 68.76)
# ('Ondo US Dollar Yield', 'usdy', 98.85, 105.8)
# ...

# %%
cursor.execute("""SELECT name, avg(market_cap_rank)
from Cryptocurrencies
where total_volume > 1000000000 """)

rows = cursor.fetchall()

for row in rows:
    print(row) #Find the average market cap rank of coins with volume above $1B.
# Out:
# ('Bitcoin', 254.15165876777252)

# %%
cursor.execute("""SELECT name,symbol,date
from Cryptocurrencies
order by date desc
limit 1 """)

rows = cursor.fetchall()

for row in rows:
    print(row) #Get the most recently updated coin.
# Out:
# ('Bitcoin', 'btc', '2026-02-23')

# %%
print(Crypto_prices_df.columns) # 2 data frame top 3
# Out:
# Index(['coin_id', 'date', 'price_inr'], dtype='object')

# %%
import sqlite3

conn = sqlite3.connect("Crypto_prices.db")
cursor = conn.cursor()

# %%
# Pushing dataframe into sql

Crypto_prices_df.to_sql("Crypto_prices", conn, if_exists="replace", index=False)
# Out:
# 1098

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Crypto_prices  (
    coin_id VARCHAR(50) ,
    date DATE,
    price_inr DECIMAL(18, 6),
    FOREIGN KEY (coin_id) REFERENCES Cryptocurrencies(id))
    """)

# %%
Crypto_prices_df["date"] =  pd.to_datetime(Crypto_prices_df["date"]).dt.strftime("%Y-%m-%d") #converts data order

# %%
sql = ("""
INSERT or REPLACE INTO  Crypto_prices (coin_id, date, price_inr)
VALUES (?, ?, ? )
""")
data = Crypto_prices_df[['coin_id', 'date', 'price_inr']].values.tolist()


cursor.executemany(sql, data)
conn.commit()

# %%
cursor.execute("SELECT * FROM Crypto_prices LIMIT 10")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('bitcoin', '2025-02-24', 8341958.303704703)
# ('bitcoin', '2025-02-25', 7922797.740624487)
# ('bitcoin', '2025-02-26', 7729282.415455005)
# ('bitcoin', '2025-02-27', 7314307.147526646)
# ('bitcoin', '2025-02-28', 7397416.663356487)
# ('bitcoin', '2025-03-01', 7386259.847331922)
# ('bitcoin', '2025-03-02', 7523008.862171689)
# ('bitcoin', '2025-03-03', 8244472.61232367)
# ('bitcoin', '2025-03-04', 7521257.854514662)
# ('bitcoin', '2025-03-05', 7615008.334491884)

# %%
cursor.execute("""SELECT coin_id,date, MAX(price_inr)
               FROM Crypto_prices
               WHERE coin_id="bitcoin"
                """)
rows = cursor.fetchall()

for row in rows:
    print(row) #Find the highest daily price of Bitcoin in the last 365 days.
# Out:
# ('bitcoin', '2025-10-07', 11070472.246732509)

# %%
cursor.execute("""SELECT coin_id,date, AVG(price_inr)
               FROM Crypto_prices
               WHERE coin_id="ethereum"
               AND date >= date('now','-365 day')
               ORDER BY date
                """)
rows = cursor.fetchall()

for row in rows:
    print(row) #Calculate the average daily price of Ethereum in the past 1 year.
# Out:
# ('ethereum', '2025-02-24', 263789.89604061405)

# %%
cursor.execute("""
SELECT coin_id, date, price_inr
FROM Crypto_prices
WHERE coin_id = "bitcoin"
AND date BETWEEN '2025-02-01' AND '2025-02-28'
ORDER BY date
""")

rows = cursor.fetchall()

for row in rows:
    print(row) #Show the daily price trend of Bitcoin in January 2025./ since data for jan not available took for feb
# Out:
# ('bitcoin', '2025-02-24', 8341958.303704703)
# ('bitcoin', '2025-02-24', 8341958.303704703)
# ('bitcoin', '2025-02-25', 7922797.740624487)
# ('bitcoin', '2025-02-25', 7922797.740624487)
# ('bitcoin', '2025-02-26', 7729282.415455005)
# ('bitcoin', '2025-02-26', 7729282.415455005)
# ('bitcoin', '2025-02-27', 7314307.147526646)
# ('bitcoin', '2025-02-27', 7314307.147526646)
# ('bitcoin', '2025-02-28', 7397416.663356487)
# ('bitcoin', '2025-02-28', 7397416.663356487)

# %%
cursor.execute("""
SELECT coin_id, date,
AVG (price_inr)
FROM Crypto_prices
GROUP BY coin_id
ORDER BY avg(price_inr) DESC
LIMIT 1
""")

rows = cursor.fetchall()

for row in rows:
    print(row)#Find the coin with the highest average price over 1 year.
# Out:
# ('bitcoin', '2025-02-24', 8685946.934184808)

# %%
cursor.execute("""
SELECT AVG(price_inr)
FROM Crypto_prices
WHERE coin_id='bitcoin'
AND date LIKE '2025-02-%'
""")#Any date that starts with %

feb2025_price = cursor.fetchone()[0]
print("feb 2025 Avg Price:", feb2025_price)#avg price of feb 2025
# Out:
# feb 2025 Avg Price: 7741152.454133466

# %%
cursor.execute("""
SELECT AVG(price_inr)
FROM Crypto_prices
WHERE coin_id='bitcoin'
AND date LIKE '2026-02-%'
""")

feb2026_price = cursor.fetchone()[0]
print("feb 2026 Avg Price:", feb2026_price)#avg price of feb 2026
# Out:
# feb 2026 Avg Price: 6331916.263712154

# %%
percent_change = ((feb2025_price - feb2026_price) / feb2025_price) * 100
print("Percentage Change:", round(percent_change,2), "%")#Get the % change in Bitcoin’s price between feb 2025 and feb 2026.
# Out:
# Percentage Change: 18.2 %

# %%
print((Oil_prices_df.columns))
# Out:
# Index(['Date', 'Price'], dtype='object')

# %%
import sqlite3
conn = sqlite3.connect("Oil_prices.db")
cursor = conn.cursor()
print("SQLite connected")
# Out:
# SQLite connected

# %%
# Pushing dataframe into sql

Oil_prices_df.to_sql("Oil_prices", conn, if_exists="replace", index=False)
# Out:
# 1520

# %%
Oil_prices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1520 non-null   datetime64[ns]
#  1   Price   1520 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 23.9 KB

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS Oil_prices (
    Date DATE PRIMARY KEY,
   Price DECIMAL(18,6)
)
""")

# %%
Oil_prices_df = Oil_prices_df.copy()
Oil_prices_df["Date"] = pd.to_datetime(Oil_prices_df["Date"]).dt.strftime("%Y-%m-%d")

# %%
sql = """
INSERT OR REPLACE INTO Oil_prices (Date, Price)
VALUES (?, ?)
"""



data = Oil_prices_df[['Date','Price']].values.tolist()

cursor.executemany(sql, data)
conn.commit()

# %%
cursor.execute("""
ALTER TABLE Oil_prices
RENAME COLUMN Date TO date
""")
cursor.execute("""
ALTER TABLE Oil_prices
RENAME COLUMN Price TO price_inr
""")

# %%
cursor.execute("""
SELECT date,price_inr
FROM Oil_prices
WHERE Date >= date('now','-5 years')
ORDER BY price_inr DESC
LIMIT 1
""")

rows = cursor.fetchall()

for row in rows:
    print(row)#Find the highest oil price in the last 5 years.
# Out:
# ('2022-03-08 00:00:00', 123.64)

# %%
cursor.execute("""
SELECT substr(date,1,4) AS year,
       AVG(price_inr)
FROM Oil_prices
GROUP BY substr(date,1,4)
ORDER BY year
LIMIT 5
""")

rows = cursor.fetchall()

for row in rows:
    print(row) #Get the average oil price per year.
# Out:
# ('2020', 39.16043650793649)
# ('2021', 68.13509960159365)
# ('2022', 94.9028685258964)
# ('2023', 77.5765322580645)
# ('2024', 76.6322400000001)

# %%
cursor.execute("""
SELECT date, price_inr
FROM Oil_prices
WHERE date BETWEEN '2020-03-01' AND '2020-04-30'
ORDER BY date
""")

rows = cursor.fetchall()

for row in rows:
    print(row) #Show oil prices during COVID crash (March–April 2020).
# Out:
# ('2020-03-02', 46.78)
# ('2020-03-02 00:00:00', 46.78)
# ('2020-03-03', 47.27)
# ('2020-03-03 00:00:00', 47.27)
# ('2020-03-04', 46.78)
# ('2020-03-04 00:00:00', 46.78)
# ('2020-03-05', 45.9)
# ('2020-03-05 00:00:00', 45.9)
# ('2020-03-06', 41.14)
# ('2020-03-06 00:00:00', 41.14)
# ('2020-03-09', 31.05)
# ('2020-03-09 00:00:00', 31.05)
# ('2020-03-10', 34.47)
# ('2020-03-10 00:00:00', 34.47)
# ('2020-03-11', 33.13)
# ('2020-03-11 00:00:00', 33.13)
# ('2020-03-12', 31.56)
# ('2020-03-12 00:00:00', 31.56)
# ('2020-03-13', 31.72)
# ('2020-03-13 00:00:00', 31.72)
# ('2020-03-16', 28.96)
# ('2020-03-16 00:00:00', 28.96)
# ('2020-03-17', 26.96)
# ('2020-03-17 00:00:00', 26.96)
# ('2020-03-18', 20.48)
# ('2020-03-18 00:00:00', 20.48)
# ('2020-03-19', 25.09)
# ('2020-03-19 00:00:00', 25.09)
# ('2020-03-20', 19.48)
# ('2020-03-20 00:00:00', 19.48)
# ('2020-03-23', 23.33)
# ('2020-03-23 00:00:00', 23.33)
# ('2020-03-24', 21.03)
# ('2020-03-24 00:00:00', 21.03)
# ('2020-03-25', 20.75)
# ...

# %%
cursor.execute("""
SELECT MIN(price_inr)
FROM Oil_prices
WHERE date >= date('now','-10 years')
""")

rows = cursor.fetchall()
for row in rows:
    print(row) #Find the lowest price of oil in the last 10 years.
# Out:
# (-36.98,)

# %%
cursor.execute("""
SELECT
    strftime('%Y', date) AS year,
    MAX(price_inr) - MIN(price_inr) AS volatility
FROM Oil_prices
GROUP BY year
ORDER BY year;
""")

rows = cursor.fetchall()#highest oil price in that year-lowest oil price in that year = volatility val
for row in rows:
    print(row) #Calculate the volatility of oil prices (max-min difference per year).
# Out:
# ('2020', 100.25)
# ('2021', 38.17)
# ('2022', 52.59)
# ('2023', 27.060000000000002)
# ('2024', 20.959999999999994)
# ('2025', 25.290000000000006)
# ('2026', 8.759999999999998)

# %%
print((stock_prices_df.columns))
# Out:
# MultiIndex([( 'Date',       ''),
#             ('^GSPC',   'Open'),
#             ('^GSPC',   'High'),
#             ('^GSPC',    'Low'),
#             ('^GSPC',  'Close'),
#             ('^GSPC', 'Volume'),
#             ('^IXIC',   'Open'),
#             ('^IXIC',   'High'),
#             ('^IXIC',    'Low'),
#             ('^IXIC',  'Close'),
#             ('^IXIC', 'Volume'),
#             ('^NSEI',   'Open'),
#             ('^NSEI',   'High'),
#             ('^NSEI',    'Low'),
#             ('^NSEI',  'Close'),
#             ('^NSEI', 'Volume')],
#            names=['Ticker', 'Price'])

# %%
gspc = stock_prices_df[
    [('Date',''),
     ('^GSPC','Open'),
     ('^GSPC','High'),
     ('^GSPC','Low'),
     ('^GSPC','Close'),
     ('^GSPC','Volume')]
].copy()

gspc.columns = ['date','open','high','low','close','volume']
gspc['ticker'] = '^GSPC'


ixic = stock_prices_df[
    [('Date',''),
     ('^IXIC','Open'),
     ('^IXIC','High'),
     ('^IXIC','Low'),
     ('^IXIC','Close'),
     ('^IXIC','Volume')]
].copy()

ixic.columns = ['date','open','high','low','close','volume']
ixic['ticker'] = '^IXIC'


nsei = stock_prices_df[
    [('Date',''),
     ('^NSEI','Open'),
     ('^NSEI','High'),
     ('^NSEI','Low'),
     ('^NSEI','Close'),
     ('^NSEI','Volume')]
].copy()

nsei.columns = ['date','open','high','low','close','volume']
nsei['ticker'] = '^NSEI'

# %%
stock_final_df = pd.concat([gspc, ixic, nsei])

# %%
stock_final_df.head()
# Out:
#         date         open         high          low        close  \
# 1 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 2 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 3 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 4 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
# 5 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049
#
#          volume ticker
# 1  3.459930e+09  ^GSPC
# 2  3.484700e+09  ^GSPC
# 3  3.702460e+09  ^GSPC
# 4  3.435910e+09  ^GSPC
# 5  3.726840e+09  ^GSPC

# %%
import sqlite3

# Connect to database (creates if not exists)
conn = sqlite3.connect('stocks.db')
cursor = conn.cursor()

# Insert dataframe into table
stock_final_df.to_sql('stocks', conn, if_exists='replace', index=False)

# Create table if not exists
cursor.execute('''
CREATE TABLE IF NOT EXISTS stocks (
    date DATE,
    open DECIMAL(18, 6),
    high DECIMAL(18, 6),
    low DECIMAL(18, 6),
    close DECIMAL(18, 6),
    volume BIGINT,
    ticker VARCHAR(20)
)
''')
stock_final_df["date"] =  pd.to_datetime(stock_final_df["date"]).dt.date

# Check inserted data
cursor.execute("SELECT * FROM stocks LIMIT 5")
print(cursor.fetchall())

# Close connection
conn.close()
# Out:
# [('2020-01-02 00:00:00', 3244.669921875, 3258.139892578125, 3235.530029296875, 3257.85009765625, 3459930000.0, '^GSPC'), ('2020-01-03 00:00:00', 3226.360107421875, 3246.14990234375, 3222.340087890625, 3234.85009765625, 3484700000.0, '^GSPC'), ('2020-01-06 00:00:00', 3217.550048828125, 3246.840087890625, 3214.639892578125, 3246.280029296875, 3702460000.0, '^GSPC'), ('2020-01-07 00:00:00', 3241.860107421875, 3244.909912109375, 3232.429931640625, 3237.179931640625, 3435910000.0, '^GSPC'), ('2020-01-08 00:00:00', 3238.590087890625, 3267.070068359375, 3236.669921875, 3253.050048828125, 3726840000.0, '^GSPC')]

# %%
import sqlite3

# Re-establish connection to the database
conn = sqlite3.connect('stocks.db')
cursor = conn.cursor()

cursor.execute("""
SELECT date, open, high, low, close, volume
FROM stocks
WHERE ticker = '^NSEI'
ORDER BY date
""")#Get all stock prices for a given ticker

rows = cursor.fetchall()

for row in rows:
    print(row)

# Close the connection after use
conn.close()
# Out:
# ('2020-01-02 00:00:00', 12198.5498046875, 12289.900390625, 12195.25, 12282.2001953125, 407700.0)
# ('2020-01-03 00:00:00', 12261.099609375, 12265.599609375, 12191.349609375, 12226.650390625, 428800.0)
# ('2020-01-06 00:00:00', 12170.599609375, 12179.099609375, 11974.2001953125, 11993.0498046875, 396500.0)
# ('2020-01-07 00:00:00', 12079.099609375, 12152.150390625, 12005.349609375, 12052.9501953125, 447800.0)
# ('2020-01-08 00:00:00', 11939.099609375, 12044.9501953125, 11929.599609375, 12025.349609375, 446000.0)
# ('2020-01-09 00:00:00', 12153.150390625, 12224.0498046875, 12132.5498046875, 12215.900390625, 477500.0)
# ('2020-01-10 00:00:00', 12271.0, 12311.2001953125, 12213.2001953125, 12256.7998046875, 660600.0)
# ('2020-01-13 00:00:00', 12296.7001953125, 12337.75, 12285.7998046875, 12329.5498046875, 501000.0)
# ('2020-01-14 00:00:00', 12333.099609375, 12374.25, 12308.7001953125, 12362.2998046875, 616300.0)
# ...

# %%
import sqlite3

# Re-establish connection to the database
conn = sqlite3.connect('stocks.db')
cursor = conn.cursor()

cursor.execute("""
SELECT date, ticker,close
FROM stocks
WHERE ticker = '^IXIC'
ORDER BY close DESC
LIMIT 1
""")


rows = cursor.fetchall()

for row in rows:
    print(row)#Find the highest closing price for NASDAQ (^IXIC)
# Out:
# ('2025-10-29 00:00:00', '^IXIC', 23958.470703125)

# %%
cursor.execute("""
SELECT date, high,low,
(high - low) AS price_difference
FROM stocks
WHERE ticker = '^GSPC'
ORDER BY price_difference DESC
LIMIT 5
""")


rows = cursor.fetchall()

for row in rows:
    print(row)#List top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)
# Out:
# ('2025-04-09 00:00:00', 5481.33984375, 4948.43017578125, 532.90966796875)
# ('2025-04-07 00:00:00', 5246.56982421875, 4835.0400390625, 411.52978515625)
# ('2025-04-08 00:00:00', 5267.47021484375, 4910.419921875, 357.05029296875)
# ('2025-11-20 00:00:00', 6770.35009765625, 6534.0498046875, 236.30029296875)
# ('2025-04-04 00:00:00', 5292.14013671875, 5069.89990234375, 222.240234375)

# %%
cursor.execute("""
SELECT
    ticker,
    strftime('%Y-%m', date) AS month,
    AVG(close)
FROM stocks
GROUP BY ticker, month
ORDER BY ticker, month
LIMIT 20
""")


rows = cursor.fetchall()

for row in rows:
    print(row)#Get monthly average closing price for each ticker
# Out:
# ('^GSPC', '2020-01', 3278.202857607887)
# ('^GSPC', '2020-02', 3273.956637912326)
# ('^GSPC', '2020-03', 2641.449044363839)
# ('^GSPC', '2020-04', 2775.8244357638887)
# ('^GSPC', '2020-05', 2924.287353515625)
# ('^GSPC', '2020-06', 3104.6609330610795)
# ('^GSPC', '2020-07', 3207.6190962357955)
# ('^GSPC', '2020-08', 3391.7100190662204)
# ('^GSPC', '2020-09', 3365.516671316964)
# ('^GSPC', '2020-10', 3422.0466657366073)
# ('^GSPC', '2020-11', 3540.628323025174)
# ('^GSPC', '2020-12', 3695.3100142045455)
# ('^GSPC', '2021-01', 3790.6444498697915)
# ('^GSPC', '2021-02', 3883.4321160567433)
# ('^GSPC', '2021-03', 3906.25048828125)
# ('^GSPC', '2021-04', 4140.348427220395)
# ('^GSPC', '2021-05', 4170.762669613487)
# ('^GSPC', '2021-06', 4238.48954634233)
# ('^GSPC', '2021-07', 4363.963940429688)
# ('^GSPC', '2021-08', 4456.259556361607)

# %%
cursor.execute("""
SELECT
    AVG(volume)
FROM stocks
WHERE ticker = '^NSEI'
AND date BETWEEN '2024-01-01' AND '2024-12-31'
""")

rows = cursor.fetchall()

for row in rows:
    print(row)#Get average trading volume of NSEI in 2024
# Out:
# (316511.39240506326,)

# %% [markdown]
# merge 4 datas

# %%
for db in ["Crypto_prices.db","Cryptocurrencies.db","Oil_prices.db","stocks.db"]:
    conn = sqlite3.connect(db)
    cursor = conn.cursor()

    cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
    print(db, "->", cursor.fetchall())

    conn.close()
# Out:
# Crypto_prices.db -> [('Crypto_prices',)]
# Cryptocurrencies.db -> [('Cryptocurrencies',)]
# Oil_prices.db -> [('Oil_prices',)]
# stocks.db -> [('stocks',)]

# %%
merged_df = pd.concat(
    [Cryptocurrencies_df,Crypto_prices_df,Oil_prices_df,stock_prices_df],
    axis=1
)


Cryptocurrencies_df,Crypto_prices_df,Oil_prices_df,stock_prices_df
# Out:
# (                     id  symbol                 name  current_price  \
#  0               bitcoin     btc              Bitcoin   5.978426e+06
#  1              ethereum     eth             Ethereum   1.712600e+05
#  2                tether    usdt               Tether   9.084000e+01
#  3                ripple     xrp                  XRP   1.243600e+02
#  4           binancecoin     bnb                  BNB   5.462700e+04
#  ...                 ...     ...                  ...            ...
#  1245      bitrise-token   brise              Bitgert   1.960000e-06
#  1246      landwolf-0x67    wolf             LandWolf   8.572700e-04
#  1247      localcoinswap     lcs        LocalCoinSwap   2.011000e+01
#  1248  bitcoin-usd-btcfi  btcusd  Bitcoin USD (BTCFi)   9.040000e+01
#  1249               pivx    pivx                 PIVX   7.620000e+00
#
#             market_cap  market_cap_rank  total_volume  circulating_supply  \
# ...

# %%
merged_df.head()
# Out:
#             id symbol      name  current_price    market_cap  market_cap_rank  \
# 0      bitcoin    btc   Bitcoin     5978426.00  1.194928e+14              1.0
# 1     ethereum    eth  Ethereum      171260.00  2.066518e+13              2.0
# 2       tether   usdt    Tether          90.84  1.668075e+13              3.0
# 3       ripple    xrp       XRP         124.36  7.580152e+12              4.0
# 4  binancecoin    bnb       BNB       54627.00  7.444066e+12              5.0
#
#    total_volume  circulating_supply  total_supply          ath  ...  \
# 0  3.561193e+12        1.999344e+07  1.999344e+07  11187013.00  ...
# 1  1.515937e+12        1.206924e+08  1.206924e+08    431946.00  ...
# 2  5.699465e+12        1.836242e+11  1.890912e+11       105.52  ...
# 3  2.349981e+11        6.101858e+10  9.998571e+10       313.99  ...
# 4  9.409038e+10        1.363590e+08  1.363590e+08    121422.00  ...
#
#    (^IXIC, Open) (^IXIC, High) (^IXIC, Low) (^IXIC, Close)  (^IXIC, Volume)  \
# ...

# %%
print(merged_df.columns)
# Out:
# Index([                'id',             'symbol',               'name',
#             'current_price',         'market_cap',    'market_cap_rank',
#              'total_volume', 'circulating_supply',       'total_supply',
#                       'ath',                'atl',               'date',
#                   'coin_id',               'date',          'price_inr',
#                      'Date',              'Price',         ('Date', ''),
#           ('^GSPC', 'Open'),    ('^GSPC', 'High'),     ('^GSPC', 'Low'),
#          ('^GSPC', 'Close'),  ('^GSPC', 'Volume'),    ('^IXIC', 'Open'),
#           ('^IXIC', 'High'),     ('^IXIC', 'Low'),   ('^IXIC', 'Close'),
#         ('^IXIC', 'Volume'),    ('^NSEI', 'Open'),    ('^NSEI', 'High'),
#            ('^NSEI', 'Low'),   ('^NSEI', 'Close'),  ('^NSEI', 'Volume')],
#       dtype='object')

# %%
gspc.rename(columns={('Date',''): 'date'}, inplace=True)
ixic.rename(columns={('Date',''): 'date'}, inplace=True)
nsei.rename(columns={('Date',''): 'date'}, inplace=True)

# %%
merged_df.columns = [
             'id',             'symbol',               'name',
            'current_price',         'market_cap',    'market_cap_rank',
             'total_volume', 'circulating_supply',       'total_supply',
                      'ath',                'atl',               'date',
                  'coin_id',               'date',          'price_inr',
                     'date',              'Price',         ('Date', ''),
          ('^GSPC', 'Open'),    ('^GSPC', 'High'),     ('^GSPC', 'Low'),
         ('^GSPC', 'Close'),  ('^GSPC', 'Volume'),    ('^IXIC', 'Open'),
          ('^IXIC', 'High'),     ('^IXIC', 'Low'),   ('^IXIC', 'Close'),
        ('^IXIC', 'Volume'),    ('^NSEI', 'Open'),    ('^NSEI', 'High'),
           ('^NSEI', 'Low'),   ('^NSEI', 'Close'),  ('^NSEI', 'Volume')]

# %%
merged_df.columns = [
    '_'.join(col).replace('^','') if isinstance(col, tuple) else col.replace('^','')
    for col in merged_df.columns
]

# %%
merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()] #removes duplicate date column

# %%
import sqlite3

# Re-establish connection to the database
conn = sqlite3.connect('merged_data.db')
cursor = conn.cursor()

# %%
merged_df.to_sql("merged_data",conn,if_exists="replace", index=False)

 # Pushing dataframe into sql
# Out:
# 1561

# %%
cursor.execute("""
SELECT
    'Bitcoin' AS asset,
    AVG(price_inr) AS avg_price_2025
FROM merged_data
WHERE coin_id = 'bitcoin'
  AND date BETWEEN '2026-01-01' AND '2026-12-31'

UNION ALL

SELECT
    'Oil' AS asset,
    AVG(price) AS avg_price_2025
FROM  merged_data
WHERE date BETWEEN '2026-01-01' AND '2026-12-31'
""")

results = cursor.fetchall()
for r in results:
    print(r)#Compare Bitcoin vs Oil average price in 2026.
# Out:
# ('Bitcoin', 8685946.934184814)
# ('Oil', 71.23506399999997)

# %%
print(merged_df.columns)
# Out:
# Index(['id', 'symbol', 'name', 'current_price', 'market_cap',
#        'market_cap_rank', 'total_volume', 'circulating_supply', 'total_supply',
#        'ath', 'atl', 'date', 'coin_id', 'price_inr', 'Price', 'Date_',
#        'GSPC_Open', 'GSPC_High', 'GSPC_Low', 'GSPC_Close', 'GSPC_Volume',
#        'IXIC_Open', 'IXIC_High', 'IXIC_Low', 'IXIC_Close', 'IXIC_Volume',
#        'NSEI_Open', 'NSEI_High', 'NSEI_Low', 'NSEI_Close', 'NSEI_Volume'],
#       dtype='object')

# %%
import pandas as pd#Get Bitcoin data,#Get S&P 500 close prices

cursor.execute("""
SELECT Date, price_inr, GSPC_Close AS sp500_close
FROM merged_data
WHERE coin_id = 'bitcoin'
""")

correlation = merged_df["price_inr"].corr(
    merged_df["GSPC_Close"]
)

print("Correlation between Bitcoin and S&P 500:", correlation)#Check if Bitcoin moves with S&P 500 (correlation idea).
# Out:
# Correlation between Bitcoin and S&P 500: -0.7442512652682988

# %%
cursor.execute("""
SELECT
date, Price,price_inr,
IXIC_Close AS nasdaq_close
FROM merged_data
WHERE coin_id = 'ethereum'
AND date BETWEEN '2026-01-01' AND '2026-12-31'

""")


daily_prices = cursor.fetchall()

for row in daily_prices:
    print(row)

 # Compare Ethereum and NASDAQ daily prices for 2025.
# Out:
# ('2026-02-23', 71.06, 244834.16977505904, 13756.330078125)
# ('2026-02-23', 71.64, 216983.40981432973, 13614.509765625)
# ('2026-02-23', 73.64, 217304.159336794, 13814.490234375)
# ('2026-02-23', 73.15, 202765.03870967304, 13881.7197265625)
# ('2026-02-23', 73.11, 201317.5125202556, 13924.91015625)
# ('2026-02-23', 73.31, 195516.66716854277, 13911.75)
# ('2026-02-23', 74.21, 193559.06747479382, 14020.330078125)
# ('2026-02-23', 72.98, 220175.98842114926, 14069.419921875)
# ('2026-02-23', 73.14, 187601.93013882774, 14174.1396484375)
# ('2026-02-23', 73.52, 189391.99179852934, 14072.8603515625)
# ('2026-02-23', 75.33, 194675.72885365813, 14039.6796875)
# ('2026-02-23', 75.37, 191886.11355343607, 14161.349609375)
# ('2026-02-23', 73.62, 186564.74028701626, 14030.3798828125)
# ('2026-02-23', 72.22, 191643.05645176853, 14141.48046875)
# ('2026-02-23', 72.98, 175758.37045736366, 14253.26953125)
# ('2026-02-23', 74.56, 164149.389538545, 14271.73046875)
# ...

# %%
cursor.execute("""
SELECT
    date,
    Price,
    LAG(Price) OVER (ORDER BY date) AS prev_price,
    (Price - LAG(Price) OVER (ORDER BY date)) * 100.0
        / LAG(Price) OVER (ORDER BY date) AS pct_change
FROM merged_data
""")

rows = cursor.fetchall()#Find days when oil price spiked and compare with Bitcoin price change.

for r in rows:
    print(r)
# Out:
# (None, 71.73, None, None)
# (None, 72.44, 71.73, 0.9898229471629635)
# (None, 73.79, 72.44, 1.8636112644947662)
# (None, 74.64, 73.79, 1.1519176040113759)
# (None, 74.31, 74.64, -0.44212218649517454)
# (None, 74.99, 74.31, 0.9150854528327178)
# (None, 73.99, 74.99, -1.3335111348179758)
# (None, 77.27, 73.99, 4.433031490741994)
# (None, 79.57, 77.27, 2.97657564384625)
# (None, 78.2, 79.57, -1.721754430061569)
# (None, 80.73, 78.2, 3.23529411764706)
# (None, 79.35, 80.73, -1.7094017094017213)
# (None, 78.56, 79.35, -0.9955891619407587)
# (None, 76.79, 78.56, -2.2530549898166954)
# (None, 76.12, 76.79, -0.8725094413335092)
# (None, 75.03, 76.12, -1.431949553336841)
# (None, 74.97, 75.03, -0.07996801279488508)
# (None, 73.51, 74.97, -1.9474456449246282)
# (None, 74.15, 73.51, 0.8706298462794185)
# (None, 72.94, 74.15, -1.6318273769386484)
# (None, 73.1, 72.94, 0.2193583767480074)
# (None, 72.84, 73.1, -0.3556771545827509)
# (None, 73.52, 72.84, 0.9335529928610552)
# ...

# %%
cursor.execute("""
SELECT
    date,
    coin_id,
    price_inr,
    GSPC_Close AS sp500,
    IXIC_Close AS nasdaq
FROM merged_data
WHERE coin_id IN ('bitcoin', 'ethereum', 'tether')
AND date BETWEEN '2026-01-01' AND '2026-12-31'
ORDER BY date
LIMIT 10
""")

results = cursor.fetchall()
for r in results:
    print(r)#Compare top 3 coins daily price trend vs Nifty (^NSEI).
# Out:
# ('2026-01-27', 'tether', 84.72143692477849, 4076.60009765625, 11584.5498046875)
# ('2026-02-01', 'ethereum', 186695.3649137571, 3790.929931640625, 11176.41015625)
# ('2026-02-01', 'tether', 87.02531092350665, 4411.58984375, 13679.0400390625)
# ('2026-02-04', 'tether', 85.45426169674982, 3829.25, 10353.23046875)
# ('2026-02-10', 'bitcoin', 7333947.924555619, 2746.56005859375, 7950.68017578125)
# ('2026-02-11', 'ethereum', 220583.0677146267, 4567.0, 15537.6904296875)
# ('2026-02-13', 'bitcoin', 6092367.347486159, 4195.990234375, 13738.0)
# ('2026-02-13', 'ethereum', 152837.10606631296, 4514.06982421875, 15286.6396484375)
# ('2026-02-18', 'tether', 86.04341248201443, 3824.139892578125, 10386.98046875)
# ('2026-02-19', 'ethereum', 341801.10296794504, 3900.7900390625, 11388.5)

# %%
cursor.execute("""
SELECT
    date,

    GSPC_Close AS sp500_close,
    Price AS oil_price
FROM merged_data
WHERE date BETWEEN '2026-01-01' AND '2026-12-31'
LIMIT 10
""")

results = cursor.fetchall()
for r in results:
    print(r) #Compare stock prices (^GSPC) with crude oil prices on the same dates
# Out:
# ('2026-02-23', None, 61.17)
# ('2026-02-23', 3257.85009765625, 63.0)
# ('2026-02-23', 3234.85009765625, 63.27)
# ('2026-02-23', 3246.280029296875, 62.7)
# ('2026-02-23', 3237.179931640625, 59.65)
# ('2026-02-23', 3253.050048828125, 59.56)
# ('2026-02-23', 3274.699951171875, 59.02)
# ('2026-02-23', 3265.35009765625, 58.17)
# ('2026-02-23', 3288.1298828125, 58.34)
# ('2026-02-22', 3283.14990234375, 57.86)

# %%
cursor.execute("""
SELECT
    date,
    price_inr AS bitcoin_price,
    Price AS oil_price
FROM merged_data
WHERE coin_id = 'bitcoin'
AND price_inr IS NOT NULL
AND Price IS NOT NULL
""")


results = cursor.fetchall()
for r in results:
    print(r) #Correlate Bitcoin closing price with crude oil closing price (same date)
# Out:
# ('2026-02-23', 8341958.303704703, 61.17)
# ('2026-02-23', 7922797.740624487, 63.0)
# ('2026-02-23', 7729282.415455005, 63.27)
# ('2026-02-23', 7314307.147526646, 62.7)
# ('2026-02-23', 7397416.663356487, 59.65)
# ('2026-02-23', 7386259.847331922, 59.56)
# ('2026-02-23', 7523008.862171689, 59.02)
# ('2026-02-23', 8244472.61232367, 58.17)
# ('2026-02-23', 7521257.854514662, 58.34)
# ('2026-02-22', 7615008.334491884, 57.86)
# ('2026-02-23', 7869430.047939962, 58.52)
# ('2026-02-23', 7841736.557001183, 58.55)
# ('2026-02-23', 7562231.150267524, 58.25)
# ('2026-02-23', 7503958.351863089, 56.76)
# ('2026-02-23', 7035607.792612969, 55.51)
# ('2026-02-23', 6882112.04135304, 54.09)
# ('2026-02-23', 7220111.199834512, 53.09)
# ('2026-02-23', 7311397.167011021, 53.33)
# ('2026-02-23', 7049331.751158462, 53.29)
# ('2026-02-23', 7301205.756783538, 52.19)
# ('2026-02-23', 7337203.4861049205, 51.58)
# ('2026-02-23', 7182714.546311197, 50.06)
# ('2026-02-23', 7307625.213417549, 49.59)
# ...

# %%
cursor.execute("""
SELECT
    date,
    price_inr AS ethereum_price,
    IXIC_Close AS nasdaq_price
FROM merged_data
WHERE coin_id = 'ethereum'
AND date BETWEEN '2026-01-01' AND '2026-12-31'
""")

results = cursor.fetchall()
for r in results:
    print(r)#Compare NASDAQ (^IXIC) with Ethereum price trends
# Out:
# ('2026-02-23', 244834.16977505904, 13756.330078125)
# ('2026-02-23', 216983.40981432973, 13614.509765625)
# ('2026-02-23', 217304.159336794, 13814.490234375)
# ('2026-02-23', 202765.03870967304, 13881.7197265625)
# ('2026-02-23', 201317.5125202556, 13924.91015625)
# ('2026-02-23', 195516.66716854277, 13911.75)
# ('2026-02-23', 193559.06747479382, 14020.330078125)
# ('2026-02-23', 220175.98842114926, 14069.419921875)
# ('2026-02-23', 187601.93013882774, 14174.1396484375)
# ('2026-02-23', 189391.99179852934, 14072.8603515625)
# ('2026-02-23', 194675.72885365813, 14039.6796875)
# ('2026-02-23', 191886.11355343607, 14161.349609375)
# ('2026-02-23', 186564.74028701626, 14030.3798828125)
# ('2026-02-23', 191643.05645176853, 14141.48046875)
# ('2026-02-23', 175758.37045736366, 14253.26953125)
# ('2026-02-23', 164149.389538545, 14271.73046875)
# ('2026-02-23', 167538.8977230319, 14369.7099609375)
# ('2026-02-23', 166533.75651871518, 14360.3896484375)
# ...

# %%
cursor.execute("""
SELECT
    date,
    coin_id,
    price_inr,
    GSPC_Close AS sp500,
    IXIC_Close AS nasdaq
FROM merged_data
WHERE coin_id IN ('bitcoin', 'ethereum', 'tether')
AND date BETWEEN '2026-01-01' AND '2026-12-31'
ORDER BY date
""")


results = cursor.fetchall()
for r in results:
    print(r)#Join top 3 crypto coins with stock indices for 2025
# Out:
# ('2026-01-27', 'tether', 84.72143692477849, 4076.60009765625, 11584.5498046875)
# ('2026-02-01', 'ethereum', 186695.3649137571, 3790.929931640625, 11176.41015625)
# ('2026-02-01', 'tether', 87.02531092350665, 4411.58984375, 13679.0400390625)
# ('2026-02-04', 'tether', 85.45426169674982, 3829.25, 10353.23046875)
# ('2026-02-10', 'bitcoin', 7333947.924555619, 2746.56005859375, 7950.68017578125)
# ('2026-02-11', 'ethereum', 220583.0677146267, 4567.0, 15537.6904296875)
# ('2026-02-13', 'bitcoin', 6092367.347486159, 4195.990234375, 13738.0)
# ('2026-02-13', 'ethereum', 152837.10606631296, 4514.06982421875, 15286.6396484375)
# ('2026-02-18', 'tether', 86.04341248201443, 3824.139892578125, 10386.98046875)
# ('2026-02-19', 'ethereum', 341801.10296794504, 3900.7900390625, 11388.5)
# ('2026-02-19', 'tether', 85.5849496864284, 3821.6201171875, 10547.1103515625)
# ('2026-02-19', 'tether', 91.01080876764598, 5224.6201171875, 16369.41015625)
# ...

# %%
cursor.execute("""
SELECT
     date,
    price_inr AS bitcoin_price,
    GSPC_Close AS sp500,
    IXIC_Close AS nasdaq,
    Price AS oil_price
FROM merged_data
WHERE coin_id = 'bitcoin'
ORDER BY date
LIMIT 10
""")



results = cursor.fetchall()

for r in results:
    print(r)##Multi-join: stock prices, oil prices, and Bitcoin prices for daily comparison
# Out:
# ('2026-02-10', 7333947.924555619, 2746.56005859375, 7950.68017578125, 31.56)
# ('2026-02-13', 6092367.347486159, 4195.990234375, 13738.0, 70.34)
# ('2026-02-22', 7615008.334491884, 3283.14990234375, 9251.330078125, 57.86)
# ('2026-02-23', 8341958.303704703, None, None, 61.17)
# ('2026-02-23', 7922797.740624487, 3257.85009765625, 9092.1904296875, 63.0)
# ('2026-02-23', 7729282.415455005, 3234.85009765625, 9020.76953125, 63.27)
# ('2026-02-23', 7314307.147526646, 3246.280029296875, 9071.4697265625, 62.7)
# ('2026-02-23', 7397416.663356487, 3237.179931640625, 9068.580078125, 59.65)
# ('2026-02-23', 7386259.847331922, 3253.050048828125, 9129.240234375, 59.56)
# ('2026-02-23', 7523008.862171689, 3274.699951171875, 9203.4296875, 59.02)

# %% [markdown]
# # Streamlit App

# %%
# !pip install -q streamlit
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
import subprocess
subprocess.Popen(["./cloudflared-linux-amd64", "tunnel", "--url", "http://localhost:8501"])
# !nohup /content/cloudflared-linux-amd64 tunnel --url http://localhost:8501 &
# Out:
# --2026-02-23 09:20:10--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.2.0/cloudflared-linux-amd64 [following]
# --2026-02-23 09:20:10--  https://github.com/cloudflare/cloudflared/releases/download/2026.2.0/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install streamlit-option-menu

# %%
# %%writefile project.py
# Out:
# Overwriting project.py

# %%
# %%writefile project.py

import streamlit as st
import pandas as pd
import sqlite3
from streamlit_option_menu import option_menu

# DB connection
conn = sqlite3.connect("merged_data.db")

# Page config
st.set_page_config(layout='wide')

# Menu
selected = option_menu(
    menu_title=None,
    options=["Home", "Data Exploration", "SQL Query Runner", "Top 5 Crypto Analysis"],
    orientation="horizontal"
)

# Home Page
if selected == "Home":
    st.title("Cross-Market Analysis: Crypto, Oil & Stocks with python & SQL ")
# Out:
# Overwriting project.py

# %%
# %%writefile project.py


import streamlit as st
import pandas as pd
import sqlite3
from streamlit_option_menu import option_menu

# MENU
selected = option_menu(
    menu_title=None,
    options=["Home", "Data Exploration", "SQL Query Runner", "Top 5 Crypto Analysis"],
    orientation="horizontal"
)

if selected == "Home":
    st.title("Cross Market Analysis")

elif selected == "Data Exploration":
    st.title("Cross Market Overview")

    # DB connection
    conn = sqlite3.connect("merged_data.db")

    # Load data
    df = pd.read_sql_query("SELECT * FROM merged_data", conn)

    # Convert date
    df['date'] = pd.to_datetime(df['date'])

    # DATE FILTER
    start_date = st.date_input("Start Date", df['date'].min(), key="start")
    end_date = st.date_input("End Date", df['date'].max(), key="end")

    # Filter data
    filtered_df = df[
        (df['date'] >= pd.to_datetime(start_date)) &
        (df['date'] <= pd.to_datetime(end_date))
    ]

    # SELECT BOX
    option = st.selectbox(
        "Select Analysis",
        [
            "Bitcoin Avg Price",
            "Oil Avg Price",
            "S&P 500 Avg",
            "NIFTY Avg"
        ],
        key="analysis"
    )

    # CALCULATIONS
    if option == "Bitcoin Avg Price":
        result = filtered_df[filtered_df['coin_id'] == 'bitcoin']['price_inr'].mean()
        st.metric("Bitcoin Average Price", round(result, 2))

    elif option == "Oil Avg Price":
        result = filtered_df['Price'].mean()
        st.metric("Oil Average Price", round(result, 2))

    elif option == "S&P 500 Avg":
        result = filtered_df['GSPC_Close'].mean()
        st.metric("S&P 500 Avg Close", round(result, 2))

    elif option == "NIFTY Avg":
        result = filtered_df['NSEI_Close'].mean()
        st.metric("NIFTY Avg Close", round(result, 2))

    # SHOW DATA
    st.subheader("Filtered Data")
    st.dataframe(filtered_df)
# Out:
# Overwriting project.py

# %%
# %%writefile project.py


import streamlit as st
import pandas as pd
import sqlite3
from streamlit_option_menu import option_menu

# MENU
selected = option_menu(
    menu_title=None,
    options=["Home", "Data Exploration", "SQL Query Runner", "Top 5 Crypto Analysis"],
    orientation="horizontal"
)




if selected == "Home":
    st.title("Cross Market Analysis")

elif selected == "Data Exploration":
    st.title("Cross Market Overview")



elif selected == "SQL Query Runner":
    st.title("SQL Query Runner")

    conn = sqlite3.connect("Cryptocurrencies.db")



    queries = {

    # ------------------ CRYPTOCURRENCIES ------------------
    "Top 3 Cryptos by Market Cap": {
        "query": """SELECT * FROM Cryptocurrencies
                    ORDER BY market_cap_rank ASC
                    LIMIT 3""",
        "db": "Cryptocurrencies.db"
    },

    "Circulating Supply > 90%": {
        "query": """SELECT id,symbol,name,circulating_supply,total_supply
                    FROM Cryptocurrencies
                    WHERE circulating_supply > 0.9 * total_supply""",
        "db": "Cryptocurrencies.db"
    },

    "Coins Near ATH": {
        "query": """SELECT name,symbol,current_price,ath
                    FROM Cryptocurrencies
                    WHERE current_price >= 0.9 * ath""",
        "db": "Cryptocurrencies.db"
    },

    "Avg Market Rank (>1B Volume)": {
        "query": """SELECT AVG(market_cap_rank)
                    FROM Cryptocurrencies
                    WHERE total_volume > 1000000000""",
        "db": "Cryptocurrencies.db"
    },

    "Most Recent Coin": {
        "query": """SELECT name,symbol,date
                    FROM Cryptocurrencies
                    ORDER BY date DESC
                    LIMIT 1""",
        "db": "Cryptocurrencies.db"
    },

    # ------------------ CRYPTO PRICES ------------------
    "Bitcoin Max Price": {
        "query": """SELECT coin_id,date,MAX(price_inr)
                    FROM Crypto_prices
                    WHERE coin_id='bitcoin'""",
        "db": "Crypto_prices.db"
    },

    "Bitcoin Feb 2025 Prices": {
        "query": """SELECT coin_id,date,price_inr
                    FROM Crypto_prices
                    WHERE coin_id='bitcoin'
                    AND date BETWEEN '2025-02-01' AND '2025-02-28'""",
        "db": "Crypto_prices.db"
    },

    "Highest Avg Price Coin": {
        "query": """SELECT coin_id,AVG(price_inr)
                    FROM Crypto_prices
                    GROUP BY coin_id
                    ORDER BY AVG(price_inr) DESC
                    LIMIT 1""",
        "db": "Crypto_prices.db"
    },

    "Bitcoin Avg Feb 2025": {
        "query": """SELECT AVG(price_inr)
                    FROM Crypto_prices
                    WHERE coin_id='bitcoin'
                    AND date LIKE '2025-02-%'""",
        "db": "Crypto_prices.db"
    },

    "Bitcoin Avg Feb 2026": {
        "query": """SELECT AVG(price_inr)
                    FROM Crypto_prices
                    WHERE coin_id='bitcoin'
                    AND date LIKE '2026-02-%'""",
        "db": "Crypto_prices.db"
    },

    # ------------------ OIL ------------------
    "Highest Oil Price (5Y)": {
        "query": """SELECT date,price_inr
                    FROM Oil_prices
                    WHERE date >= date('now','-5 years')
                    ORDER BY price_inr DESC
                    LIMIT 1""",
        "db": "Oil_prices.db"
    },

    "Oil Avg Per Year": {
        "query": """SELECT substr(date,1,4) AS year,AVG(price_inr)
                    FROM Oil_prices
                    GROUP BY year""",
        "db": "Oil_prices.db"
    },

    "Oil COVID Crash": {
        "query": """SELECT date,price_inr
                    FROM Oil_prices
                    WHERE date BETWEEN '2020-03-01' AND '2020-04-30'""",
        "db": "Oil_prices.db"
    },

    "Lowest Oil (10Y)": {
        "query": """SELECT MIN(price_inr)
                    FROM Oil_prices
                    WHERE date >= date('now','-10 years')""",
        "db": "Oil_prices.db"
    },

    "Oil Volatility": {
        "query": """SELECT strftime('%Y',date) AS year,
                           MAX(price_inr)-MIN(price_inr) AS volatility
                    FROM Oil_prices
                    GROUP BY year""",
        "db": "Oil_prices.db"
    },

    # ------------------ STOCKS ------------------
    "NSEI Stock Data": {
        "query": """SELECT date,open,high,low,close,volume
                    FROM stocks
                    WHERE ticker='^NSEI'""",
        "db": "stocks.db"
    },

    "NASDAQ Highest Close": {
        "query": """SELECT date,ticker,close
                    FROM stocks
                    WHERE ticker='^IXIC'
                    ORDER BY close DESC
                    LIMIT 1""",
        "db": "stocks.db"
    },

    "S&P500 Volatility Days": {
        "query": """SELECT date,high,low,(high-low) AS diff
                    FROM stocks
                    WHERE ticker='^GSPC'
                    ORDER BY diff DESC
                    LIMIT 5""",
        "db": "stocks.db"
    },

    "Monthly Avg Stocks": {
        "query": """SELECT ticker,strftime('%Y-%m',date) AS month,
                           AVG(close)
                    FROM stocks
                    GROUP BY ticker,month""",
        "db": "stocks.db"
    },

    "NSEI Volume 2024": {
        "query": """SELECT AVG(volume)
                    FROM stocks
                    WHERE ticker='^NSEI'
                    AND date BETWEEN '2024-01-01' AND '2024-12-31'""",
        "db": "stocks.db"
    },

    # ------------------ MERGED DATA ------------------
    "Bitcoin vs Oil 2026": {
        "query": """SELECT 'Bitcoin' AS asset,AVG(price_inr)
                    FROM merged_data
                    WHERE coin_id='bitcoin'
                    UNION ALL
                    SELECT 'Oil',AVG(price)
                    FROM merged_data""",
        "db": "merged_data.db"
    },

    "Bitcoin vs S&P500": {
        "query": """SELECT date,price_inr,GSPC_Close
                    FROM merged_data
                    WHERE coin_id='bitcoin'""",
        "db": "merged_data.db"
    },

    "Ethereum vs NASDAQ": {
        "query": """SELECT date,price_inr,IXIC_Close
                    FROM merged_data
                    WHERE coin_id='ethereum'""",
        "db": "merged_data.db"
    },

    "Bitcoin Oil Correlation Data": {
        "query": """SELECT date,price_inr AS bitcoin_price,Price AS oil_price
                    FROM merged_data
                    WHERE coin_id='bitcoin'""",
        "db": "merged_data.db"
    },

    "Top 3 Coins vs Market": {
        "query": """SELECT date,coin_id,price_inr,GSPC_Close,IXIC_Close
                    FROM merged_data
                    WHERE coin_id IN ('bitcoin','ethereum','tether')
                    LIMIT 10""",
        "db": "merged_data.db"
    },

    "Stock vs Oil": {
        "query": """SELECT date,GSPC_Close,Price
                    FROM merged_data
                    LIMIT 10""",
        "db": "merged_data.db"
    },

    "Bitcoin Full Market View": {
        "query": """SELECT date,price_inr,GSPC_Close,IXIC_Close,Price
                    FROM merged_data
                    WHERE coin_id='bitcoin'
                    LIMIT 10""",
        "db": "merged_data.db"
    }
}

    #  ALL QUERIES
    selected_query = st.selectbox("Select SQL Query", list(queries.keys()))

    st.code(queries[selected_query]["query"], language="sql")

    if st.button("Run Query"):
      query = queries[selected_query]["query"]
      db = queries[selected_query]["db"]

      conn = sqlite3.connect(db)

      result = pd.read_sql_query(query, conn)
      st.dataframe(result)
# Out:
# Overwriting project.py

# %%
# %%writefile project.py


import streamlit as st
import pandas as pd
import sqlite3
from streamlit_option_menu import option_menu

# MENU
selected = option_menu(
    menu_title=None,
    options=["Home", "Data Exploration", "SQL Query Runner", "Top 5 Crypto Analysis"],
    orientation="horizontal"
)

if selected == "Home":
    st.title("Cross Market Analysis")

elif selected == "Data Exploration":
    st.title("Cross Market Overview")

elif selected == "SQL Query Runner":
    st.title("SQL Query Runner")

elif selected == "Top 5 Crypto Analysis":
    st.title("Top 5 Crypto Analysis")

    import sqlite3
    import pandas as pd

    conn = sqlite3.connect("Crypto_prices.db")

    # ---- Get Top 3 coins ----
    top_crypto_query = """
        SELECT DISTINCT coin_id
        FROM Crypto_prices
        LIMIT 3
    """
    top_crypto_df = pd.read_sql_query(top_crypto_query, conn)

    crypto_list = top_crypto_df["coin_id"].tolist()

    # ---- Select Crypto ----
    selected_crypto = st.selectbox("Select Cryptocurrency", crypto_list)

    # ---- Load Data for selected crypto ----
    query = f"""
        SELECT date, price_inr
        FROM Crypto_prices
        WHERE coin_id = '{selected_crypto}'
    """
    df = pd.read_sql_query(query, conn)

    # ---- Convert Date ----
    df["date"] = pd.to_datetime(df["date"])

    # ---- Date Filter ----
    start_date = st.date_input("Start Date", df["date"].min())
    end_date = st.date_input("End Date", df["date"].max())

    filtered_df = df[(df["date"] >= pd.to_datetime(start_date)) &
                     (df["date"] <= pd.to_datetime(end_date))]

    # ---- Line Chart (Optional) ----
    st.subheader("Daily Price Trend")
    st.line_chart(filtered_df.set_index("date")["price_inr"])

    # ---- Table ----
    st.subheader("Daily Price Data")
    st.dataframe(filtered_df)

    conn.close()
# Out:
# Overwriting project.py

# %%
# !ls
# Out:
# cloudflared-linux-amd64    Crypto_prices.db  nohup.out	    sample_data
# cloudflared-linux-amd64.1  logs.txt	     Oil_prices.db  stocks.db
# Cryptocurrencies.db	   merged_data.db    project.py

# %%
# !streamlit run /content/project.py &>/content/logs.txt &

# %%
# !grep -o 'https://.*\.trycloudflare.com' nohup.out | head -n 1 | xargs -I {} echo "Your tunnel url {}"
# Out:
# Your tunnel url https://beginning-electrical-drove-larger.trycloudflare.com
